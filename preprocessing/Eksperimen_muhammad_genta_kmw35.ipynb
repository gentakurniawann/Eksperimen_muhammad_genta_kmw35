# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = '../dataset_raw/breast_cancer.csv'
df = pd.read_csv(data_path)
df.head()
# Out:
#    mean radius  mean texture  ...  worst dimension
# 0        17.99         10.38  ...           0.11890
# 1        20.57         17.77  ...           0.08902

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
os.makedirs('dataset_preprocessing', exist_ok=True)
df.to_csv('dataset_preprocessing/breast_cancer_processed.csv', index=False)
print('Data saved!')
# Out:
# Data saved!
