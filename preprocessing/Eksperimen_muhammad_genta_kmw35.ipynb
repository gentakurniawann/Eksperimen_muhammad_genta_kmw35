# %% [markdown]
# # Proyek Sistem Machine Learning: Eksperimen Breast Cancer
# **Nama:** muhammad_genta_kmw35

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
import os

# %% [markdown]
# ## 1. Data Loading

# %%
data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target
df.head()

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %%
# Cek missing values
print(df.isnull().sum())

# Distribusi target (0: malignant, 1: benign)
sns.countplot(x='target', data=df)
plt.title('Distribusi Kelas Target')
plt.show()

# %% [markdown]
# ## 3. Data Preprocessing

# %%
# Menghapus duplikat atau missing values jika ada
df_cleaned = df.dropna()

# Menyimpan data yang sudah diproses
os.makedirs('../breast_cancer_preprocessing', exist_ok=True)
df_cleaned.to_csv('../breast_cancer_preprocessing/breast_cancer_processed.csv', index=False)
print("Data berhasil diproses dan disimpan.")
